# %% [markdown]
# # Capstone project - severity of car accidents in Catalonia between 2010 and 2020
# ## Applied data science capstone/ IBM

# %%
import pandas as pd
import numpy as np

# %%
# pip install wget
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\user\anaconda3\lib\site-packages (3.2)

# %%
# Get the data
# !wget -O traffic_accidents.csv https://analisi.transparenciacatalunya.cat/resource/rmgc-ncpb.csv
# Out:
# "wget" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
df = pd.read_csv('Accidents_de_tr_nsit_amb_morts_o_ferits_greus_a_Catalunya.csv')
df.head()
# Out:
#     Any         zona         dat    via        pk                nomMun  \
# 0  2010  Zona urbana  25/01/2010     SE  999999.0     CANOVES I SAMALUS
# 1  2010    Carretera  31/10/2010  N-240     999.0                LLEIDA
# 2  2010    Carretera  17/05/2010   N-II    7087.0  FORNELLS DE LA SELVA
# 3  2010  Zona urbana  21/08/2010     SE  999999.0             BARCELONA
# 4  2010  Zona urbana  07/05/2010     SE  999999.0              BADALONA
#
#             nomCom     nomDem  F_MORTS  F_FERITS_GREUS  ...  D_SUPERFICIE  \
# 0  Valles Oriental  Barcelona        0               1  ...     Sec i net
# 1           Segria     Lleida        0               1  ...     Sec i net
# 2          Girones     Girona        1               0  ...     Sec i net
# 3       Barcelones  Barcelona        0               2  ...     Sec i net
# 4       Barcelones  Barcelona        0               1  ...     Sec i net
#
#                                        D_TIPUS_VIA  D_TITULARITAT_VIA  \
# 0  Via urbana( inclou carrer i carrer residencial)                NaN
# 1                           Carretera convencional            Estatal
# 2                           Carretera convencional            Estatal
# 3  Via urbana( inclou carrer i carrer residencial)                NaN
# 4  Via urbana( inclou carrer i carrer residencial)                NaN
#
#    D_TRACAT_ALTIMETRIC                 D_VENT    grupDiaLab   hor  grupHor  \
# 0                  NaN  Calma, vent molt suau       Feiners  2333      Nit
# 1                  Pla  Calma, vent molt suau  CapDeSetmana     1      Nit
# 2      Rampa o pendent  Calma, vent molt suau       Feiners  1527    Tarda
# 3                  NaN  Calma, vent molt suau  CapDeSetmana   223      Nit
# 4                  NaN  Calma, vent molt suau  CapDeSetmana  1745    Tarda
#
#                                     tipAcc    tipDia
# 0           Col.lisió de vehicles en marxa  dill-dij
# 1  Sortida de la calcada sense especificar        dg
# 2           Col.lisió de vehicles en marxa  dill-dij
# 3           Col.lisió de vehicles en marxa       dis
# 4                     Bolcada a la calcada       div
#
# [5 rows x 58 columns]
